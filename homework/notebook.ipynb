# %%
import os
import gzip
import json
import pickle

import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.svm import SVC
from sklearn.metrics import (
    precision_score,
    balanced_accuracy_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
train_df = pd.read_csv("../files/input/train_data.csv.zip")
test_df = pd.read_csv("../files/input/test_data.csv.zip")


def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    df = df.rename(columns={"default payment next month": "default"})
    if "ID" in df.columns:
        df = df.drop(columns=["ID"])
    df = df[(df["EDUCATION"] != 0) & (df["MARRIAGE"] != 0)]
    df["EDUCATION"] = df["EDUCATION"].apply(lambda v: 4 if v > 4 else v)
    df = df.dropna()
    return df


train_df = clean_data(train_df)
test_df = clean_data(test_df)

# %%
X_train = train_df.drop(columns=["default"])
y_train = train_df["default"]

X_test = test_df.drop(columns=["default"])
y_test = test_df["default"]

# %%
categorical_features = ["SEX", "EDUCATION", "MARRIAGE"]
numerical_features = [c for c in X_train.columns if c not in categorical_features]

preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore", sparse_output=False),
            categorical_features,
        ),
        ("num", "passthrough", numerical_features),
    ],
    remainder="drop",
    verbose_feature_names_out=False,
)

pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("pca", PCA()),
        ("scaler", StandardScaler()),
        ("select", SelectKBest(score_func=f_classif)),
        ("svm", SVC()),
    ]
)

# %%
total_base_features = len(categorical_features) + len(numerical_features)

param_grid = {
    "select__k": [10, 15, 20, total_base_features],
    "svm__C": [0.1, 1, 10],
    "svm__gamma": ["scale", 0.1, 0.01],
    "svm__kernel": ["rbf"],
}

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=10,
    scoring="balanced_accuracy",
    n_jobs=-1,
    verbose=2,
    refit=True,
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.3s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.3s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.4s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.5s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.5s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.7s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.4s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.5s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   6.7s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   6.7s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.3s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   7.7s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.5s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   7.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   7.7s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.5s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   7.8s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.6s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.2s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.1s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.1s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.2s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.3s
# [CV] END select__k=10, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.3s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   9.1s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   9.5s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.3s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.5s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.6s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.6s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.3s
# [CV] END select__k=10, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   8.3s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   8.7s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   8.7s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   8.6s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   9.2s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   9.0s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=   9.2s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.7s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.0s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.0s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.9s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=   8.0s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.9s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.8s
# [CV] END select__k=10, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=   7.9s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  13.9s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.0s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.6s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=10, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  14.6s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  15.1s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  14.9s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  15.7s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  15.6s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  15.5s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  16.0s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  13.9s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  14.5s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   8.9s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   8.8s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.0s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.0s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.0s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.1s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   8.7s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.4s
# [CV] END select__k=10, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=   9.5s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   9.6s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   9.6s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  10.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  10.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  10.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   9.7s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   9.9s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   9.8s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   9.8s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=   9.9s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.0s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.7s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=   9.3s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.0s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.2s
# [CV] END select__k=15, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.1s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  12.1s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  12.0s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  12.4s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  11.7s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  12.9s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  13.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  13.4s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=15, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.3s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.4s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.0s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.1s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.3s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.5s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.6s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.8s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.4s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  11.2s
# [CV] END select__k=15, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  10.7s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  20.6s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  18.0s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  23.1s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  23.0s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  23.1s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  23.0s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  19.8s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  22.4s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  21.7s
# [CV] END select__k=15, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  21.2s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  30.0s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  25.8s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  29.8s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  31.4s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  30.1s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  31.4s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  30.3s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  31.1s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  32.0s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.5s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.4s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  31.5s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.6s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.3s
# [CV] END select__k=15, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.9s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  15.0s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.8s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.8s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  15.0s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.9s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  15.2s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.4s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  16.1s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  16.0s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  16.4s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.6s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.1s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.8s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  14.8s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.7s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.4s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.6s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf; total time=  15.5s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.1s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  12.7s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  12.8s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.3s
# [CV] END select__k=20, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.7s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.7s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  14.7s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  14.9s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.1s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.4s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.2s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.6s
# [CV] END select__k=20, svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=  15.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  26.6s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  26.9s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  26.2s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  23.9s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  25.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  24.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  24.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  24.0s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.5s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.6s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.0s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.1s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.3s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  21.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.1, svm__kernel=rbf; total time=  27.4s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  14.2s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=20, svm__C=1, svm__gamma=0.01, svm__kernel=rbf; total time=  13.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  31.7s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  32.5s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  31.7s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  29.3s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  33.3s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  32.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  34.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  35.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  34.9s
# [CV] END select__k=20, svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=  38.5s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  53.4s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  51.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  47.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  52.6s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  49.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  48.3s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  16.9s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  17.1s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  17.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  16.9s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  46.2s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  46.6s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  16.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  16.9s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  17.2s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  18.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  42.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  18.0s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.01, svm__kernel=rbf; total time=  17.8s
# [CV] END select__k=20, svm__C=10, svm__gamma=0.1, svm__kernel=rbf; total time=  48.5s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  16.5s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  16.3s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  17.0s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  16.8s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  17.1s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  16.9s
# [CV] END select__k=23, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=  16.0s

# %%
os.makedirs("../files/models", exist_ok=True)
with gzip.open("../files/models/model.pkl.gz", "wb") as f:
    pickle.dump(grid_search, f)

# %%
def calculate_metrics(model, x, y, dataset_name: str) -> dict:
    y_pred = model.predict(x)
    return {
        "type": "metrics",
        "dataset": dataset_name,
        "precision": precision_score(y, y_pred, zero_division=0),
        "balanced_accuracy": balanced_accuracy_score(y, y_pred),
        "recall": recall_score(y, y_pred, zero_division=0),
        "f1_score": f1_score(y, y_pred, zero_division=0),
    }


metrics = []
metrics.append(calculate_metrics(grid_search, X_train, y_train, "train"))
metrics.append(calculate_metrics(grid_search, X_test, y_test, "test"))

# %%
def calculate_confusion_matrix(model, x, y, dataset_name: str) -> dict:
    y_pred = model.predict(x)
    cm = confusion_matrix(y, y_pred)
    return {
        "type": "cm_matrix",
        "dataset": dataset_name,
        "true_0": {
            "predicted_0": int(cm[0, 0]),
            "predicted_1": int(cm[0, 1]),
        },
        "true_1": {
            "predicted_0": int(cm[1, 0]),
            "predicted_1": int(cm[1, 1]),
        },
    }


metrics.append(calculate_confusion_matrix(grid_search, X_train, y_train, "train"))
metrics.append(calculate_confusion_matrix(grid_search, X_test, y_test, "test"))

os.makedirs("../files/output", exist_ok=True)
with open("../files/output/metrics.json", "w", encoding="utf-8") as f:
    for row in metrics:
        f.write(json.dumps(row) + "\n")
